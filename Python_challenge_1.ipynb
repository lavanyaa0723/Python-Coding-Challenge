# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanyaa0723/Python-Coding-Challenge/blob/main/Python_challenge_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Challenge 1
# Student Profile Creator

# %%
# 1. create variables for student information
student_name = "Lavanyaa"
student_age = 19
favourite_subject = ["Social","Maths","English"]

# %%
# 2. Display Student Informtion
print("-- Students Profile --")
print("Student Name: ",student_name)
print("Student Age: ",student_age)
print("Favourite Subjects: ",favourite_subject)
# Out:
# -- Students Profile --
# Student Name:  Lavanyaa
# Student Age:  19
# Favourite Subjects:  ['Social', 'Maths', 'English']

# %%
# 3.Ask Student to Enter their new fav subject
new_fav_subject = input("Enter your new favourite subject: ")
# Out:
# Enter your new favourite subject: computer

# %%
# 4. Add to the List
favourite_subject.append(new_fav_subject)
print(favourite_subject)
# Out:
# ['Social', 'Maths', 'English', 'computer', 'computer']

# %%
#5. Display Updated List of Subjects
print("-- Updated Subjects --")
print("Updated Favourite Subjects: ",favourite_subject)
# Out:
# -- Updated Subjects --
# Updated Favourite Subjects:  ['Social', 'Maths', 'English', 'computer']
